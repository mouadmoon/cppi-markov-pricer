# %%
import numpy as np
from grid import Grid
from models import KouModel
from transition_matrix import TransitionMatrix
from pricerClosedFormulas import CPPIPricer

# %% [markdown]
# # Import Required Libraries
#
# Import the Python libraries used by the project workflow.

# %% [markdown]
# # CPPI Markov Pricer Presentation
#
# This notebook provides a compact, reusable presentation of the current pricing workflow.
#
# - Project: cpPI Markov Pricer
# - Main workflow: build a grid, construct a transition matrix, and price via the CPPIPricer class
# - Current focus: reproduce the KOU pricing experiment and inspect the result
